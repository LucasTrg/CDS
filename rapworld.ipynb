# %%
import pandas as pd

# %%
df=pd.read_csv("data/rap_world/rapworld.csv", sep=";")
# Out:
#                   Name       Categories  \
# 0       Trae Tha Truth           rapper
# 1             13 Block            group
# 2             Jay Rock           rapper
# 3       Droogz Brigade            group
# 4         Jeff le Nerf           rapper
# ..                 ...              ...
# 576           Omnikrom            group
# 577  Ol' Dirty Bastard  producer;rapper
# 578          Rick Ross           rapper
# 579          Lil Wayne           rapper
# 580     Peewee Longway           rapper
#
#                                                    URL  Years Active Start  \
# 0         https://en.wikipedia.org/wiki/Trae_tha_Truth              1998.0
# 1                  https://genius.com/artists/13-block              2014.0
# 2               https://en.wikipedia.org/wiki/Jay_Rock              2003.0
# 3            https://genius.com/artists/Droogz-brigade              2008.0
# 4           https://fr.wikipedia.org/wiki/Jeff_Le_Nerf              1997.0
# ..                                                 ...                 ...
# 576             https://en.wikipedia.org/wiki/Omnikrom                 NaN
# 577  https://en.wikipedia.org/wiki/Ol%27_Dirty_Bastard                 NaN
# 578            https://en.wikipedia.org/wiki/Rick_Ross                 NaN
# 579            https://en.wikipedia.org/wiki/Lil_Wayne                 NaN
# 580       https://en.wikipedia.org/wiki/Peewee_Longway                 NaN
#
#       Birthdate                                            Summary  \
# 0    1980-07-03  Frazier Othel Thompson III (born July 3, 1980)...
# 1           NaN  13 Block is a french Hip Hop group from Sevran...
# 2    1985-03-31  Johnny Reed McKinzie, Jr., (born March 31, 198...
# 3           NaN  Droogz Brigade is french hiphop group from Tou...
# 4    1982-03-17  Jeff Le Nerf is a french rapper from Grenoble....
# ..          ...                                                ...
# 576         NaN  Omnikrom is a Canadian rap, crunk, and electro...
# 577  1968-11-15  Russell Tyrone Jones better known under his st...
# 578         NaN  William Leonard Roberts II (born January 28, 1...
# 579         NaN  Dwayne Michael Carter Jr. (born September 27, ...
# 580         NaN  Quincy Lamont Williams (born August 17, 1984),...
#
#      Years Active End   Deathdate  \
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ..                ...         ...
# 576               NaN         NaN
# 577               NaN  2004-11-13
# 578               NaN         NaN
# 579               NaN         NaN
# 580               NaN         NaN
#
#                                   Clip Example YouTube         City  \
# 0            https://www.youtube.com/embed/QqKh5Bhx3YE      Houston
# 1            https://www.youtube.com/embed/ewExz3cx_RM       Sevran
# 2            https://www.youtube.com/embed/fk10RoZV4fw        Watts
# 3            https://www.youtube.com/embed/e9UbNKuxzzk     Toulouse
# 4            https://www.youtube.com/embed/kSiLpodQTBQ     Grenoble
# ..                                                 ...          ...
# 576          https://www.youtube.com/embed/lKpTfeb8qMI     Montréal
# 577          https://www.youtube.com/embed/4ITLNzPoEqs     New York
# 578  https://www.youtube.com/embed/JU9TouRnO84?list...        Miami
# 579          https://www.youtube.com/embed/UROLAsyc_KU  New Orleans
# 580          https://www.youtube.com/embed/S3n07zNGOeg      Atlanta
#
#                    Neighborhood           Coordinates
# 0                           NaN  29.674552,-95.363456
# 1                           NaN    48.929103,2.533054
# 2    Nickerson Gardens projects  33.930751,-118.24893
# 3                           NaN    43.582029,1.458244
# 4                           NaN    45.189542,5.707799
# ..                          ...                   ...
# 576                         NaN  45.484446,-73.749948
# 577                    Brooklyn  40.683065,-73.970845
# 578                  Carol City  25.897749,-80.207326
# 579                         NaN   29.96192,-90.123563
# 580                         NaN    33.75054,-84.32415
#
# [581 rows x 12 columns]

# %%
upper_left=(41.000449, -74.121283)
down_right=(40.556001, -73.060932)
