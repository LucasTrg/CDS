# %%
import pandas as pd

# %%
df=pd.read_csv("data/rap_world/rapworld.csv", sep=";")

# %%
upper_left=(41.000449, -74.121283)
down_right=(40.556001, -73.060932)

# %%
(df["Name"]=="22 GZ").any()
# Out:
# False

# %%
df["x"]=df["Coordinates"].apply(lambda x : float(x.split(",")[0]))
df["y"]=df["Coordinates"].apply(lambda x : float(x.split(",")[1]))

# %%
df[(df["x"]<upper_left[0])&(df["x"]>down_right[0])&(df["y"]<down_right[1])&(df["y"]>upper_left[1])]
# Out:
#                    Name       Categories  \
# 12             Chino XL           rapper
# 20     Afrika Bambaataa    producer / dj
# 21                U-God           rapper
# 32           Dj Premier    producer / dj
# 60              Das EFX            group
# ..                  ...              ...
# 544                 RZA  producer;rapper
# 551             MF Doom           rapper
# 574  Immortal Technique           rapper
# 575         Joey bada$$    rapper;singer
# 577   Ol' Dirty Bastard  producer;rapper
#
#                                                    URL  Years Active Start  \
# 12              https://en.wikipedia.org/wiki/Chino_XL              1992.0
# 20      https://en.wikipedia.org/wiki/Afrika_Bambaataa                 NaN
# 21                 https://en.wikipedia.org/wiki/U-God                 NaN
# 32            https://en.wikipedia.org/wiki/DJ_Premier              1984.0
# 60               https://en.wikipedia.org/wiki/Das_EFX              1988.0
# ...

# %%
df.Name["Tupac"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df.Name["Tupac"]
#
# File ~/FLEP/DS-env/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/FLEP/DS-env/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
# ...
