# %%
import pandas as pd

# %%
pd.read_csv("data/neighborhoods/wikidump.txt", sep="\t", names=["District", "Area", "Pop", "Density", "Neighborhoods"]).to_csv("data/neighborhoods/cleaned_neighborhoods.csv")

# %%
pd.read_csv("data/neighborhoods/wikidump.txt", sep="\t", names=["District", "Area", "Pop", "Density", "Neighborhoods"])
# Out:
#                District   Area       Pop  Density  \
# 0           Bronx CB 1    7.17   91,497   12,761
# 1           Bronx CB 2    5.54   52,246    9,792
# 2           Bronx CB 3    4.07   79,762   19,598
# 3           Bronx CB 4    5.28  146,441   27,735
# 4           Bronx CB 5    3.55  128,200   36,145
# 5           Bronx CB 6    4.01   83,268   20,765
# 6           Bronx CB 7    4.84  139,286   28,778
# 7           Bronx CB 8    8.83  101,731   11,521
# 8           Bronx CB 9   12.41  172,298   13,884
# 9          Bronx CB 10   16.76  120,392    7,183
# 10         Bronx CB 11    9.32  113,232   12,149
# 11         Bronx CB 12   14.56  152,344   10,463
# 12       Brooklyn CB 1   12.82  160,338   12,507
# 13       Brooklyn CB 2    7.72   98,620   12,775
# 14       Brooklyn CB 3    7.67  143,867   18,757
# 15       Brooklyn CB 4    5.31  104,358   19,653
# 16       Brooklyn CB 5   14.61  173,198   11,855
# 17       Brooklyn CB 6    9.01  104,054   11,549
# ...
